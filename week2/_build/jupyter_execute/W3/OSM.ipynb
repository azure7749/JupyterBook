# %% [markdown]
# # 台灣鐵道車站分佈圖
#
# ## 作業內容
# 利用overpass api取得全島營運中鐵路車站位置，並加以分類以呈現出捷運, 台鐵及高鐵車站的位置

# %%
import folium
import requests

# %%
def fetch_overpass_data(query):
    overpass_url = "http://overpass-api.de/api/interpreter"
    response = requests.get(overpass_url, params={'data': query})
    data = response.json()
    return data

# %%
metro_query = """
[out:json];
area["name:en"="Taiwan"]->.searchArea;
(
  node["station"="subway"]["subway"="yes"](area.searchArea);
);
out center;
"""
tra_query = """
[out:json];
area["name:en"="Taiwan"]->.searchArea;
(
  node["railway"="station"]["network:en"="TRA"](area.searchArea);
);
out center;
"""
hsr_query = """
[out:json];
area["name:en"="Taiwan"]->.searchArea;
(
node["railway"="station"]["network:en"="Taiwan High Speed Rail"](area.searchArea);
);
out center;
"""
metro_data = fetch_overpass_data(metro_query)
tra_data = fetch_overpass_data(tra_query)
hsr_data = fetch_overpass_data(hsr_query)

# %%
taiwan_center = [23.6978, 120.9605]
m = folium.Map(location=taiwan_center, zoom_start=8)

def add_markers(data, map_obj, color, station_type):
    for element in data['elements']:
        lat = element['lat']
        lon = element['lon']
        name = element['tags'].get('name', 'Unnamed Station')
        folium.Marker(
            location=[lat, lon],
            popup=f"{station_type}: {name}",
            icon=folium.Icon(color=color)
        ).add_to(map_obj)

add_markers(metro_data, m, 'blue', 'Metro Station')
add_markers(tra_data, m, 'green', 'Train Station')
add_markers(hsr_data, m, 'red', 'HSR Station')


m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7c76205c7ad6f0be3081e18068fb6666 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7c76205c7ad6f0be3081e18068fb6666&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7c76205c7ad6f0be3081e18068fb6666 = L.map(
#                 &quot;map_7c76205c7ad6f0be3081e18068fb6666&quot;,
#                 {
#                     center: [23.6978, 120.9605],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_91a5c9145abe537ada3c83a7a8fba114 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_91a5c9145abe537ada3c83a7a8fba114.addTo(map_7c76205c7ad6f0be3081e18068fb6666);
#
#
#             var marker_ff196c6710c86dbaaccbbc0a385aebb8 = L.marker(
#                 [25.0205325, 121.5283902],
#                 {}
#             ).addTo(map_7c76205c7ad6f0be3081e18068fb6666);
#
#
#             var icon_802ce4f31e8c3501e9e24b42799d5e43 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ff196c6710c86dbaaccbbc0a385aebb8.setIcon(icon_802ce4f31e8c3501e9e24b42799d5e43);
#
#
#         var popup_60dd9505bb5000fab78b258b9afb0a24 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2c5c7623b7ef25a869aeb2d702683533 = $(`&lt;div id=&quot;html_2c5c7623b7ef25a869aeb2d702683533&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Metro Station: 台電大樓&lt;/div&gt;`)[0];
#                 popup_60dd9505bb5000fab78b258b9afb0a24.setContent(html_2c5c7623b7ef25a869aeb2d702683533);
#
#
#
#         marker_ff196c6710c86dbaaccbbc0a385aebb8.bindPopup(popup_60dd9505bb5000fab78b258b9afb0a24)
#         ;
#
#
#
#
#             var marker_c50470acc32cf996a42c5be7bfc75a5c = L.marker(
#                 [25.1369644, 121.5031693],
#                 {}
#             ).addTo(map_7c76205c7ad6f0be3081e18068fb6666);
#
#
#             var icon_838666f7a563ef0962e3fad5a9bee8df = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c50470acc32cf996a42c5be7bfc75a5c.setIcon(icon_838666f7a563ef0962e3fad5a9bee8df);
#
#
#         var popup_96b9bd8bf567614afbc816eefb3a602f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1ec980164d604b28e6b8b03e2b24dde2 = $(`&lt;div id=&quot;html_1ec980164d604b28e6b8b03e2b24dde2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Metro Station: 新北投&lt;/div&gt;`)[0];
#                 popup_96b9bd8bf567614afbc816eefb3a602f.setContent(html_1ec980164d604b28e6b8b03e2b24dde2);
#
#
#
#         marker_c50470acc32cf996a42c5be7bfc75a5c.bindPopup(popup_96b9bd8bf567614afbc816eefb3a602f)
#         ;
#
#
#
#
#             var marker_d4035ce5631ee975dec6ae4275150d5a = L.marker(
#                 [24.9668719, 121.4362698],
#                 {}
#             ).addTo(map_7c76205c7ad6f0be3081e18068fb6666);
#
#
#             var icon_fd1caac09e9913db0774f98fad0ff186 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d4035ce5631ee975dec6ae4275150d5a.setIcon(icon_fd1caac09e9913db0774f98fad0ff186);
#
#
#         var popup_44ee398e8ef803b8e66112b07a323c20 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_999d2f136d60d2d2a1ea693edf300dad = $(`&lt;div id=&quot;html_999d2f136d60d2d2a1ea693edf300dad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Metro Station: 永寧&lt;/div&gt;`)[0];
#                 popup_44ee398e8ef803b8e66112b07a323c20.setContent(html_999d2f136d60d2d2a1ea693edf300dad);
#
#
#
#         marker_d4035ce5631ee975dec6ae4275150d5a.bindPopup(popup_44ee398e8ef803b8e66112b07a323c20)
#         ;
#
#
#
#
#             var marker_4b94e165ac59c096dfefc44c48ae561f = L.marker(
#                 [24.9731817, 121.444391],
#                 {}
#             ).addTo(map_7c76205c7ad6f0be3081e18068fb6666);
#
#
#             var icon_611b7723823bd7b63b4d02f84e237a25 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &
